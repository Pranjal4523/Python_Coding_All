# %% [markdown]
# ### Miscellaneous Concepts

# %% [markdown]
# - Mutable Objects: List,Dictionary, Set
# - Immutable Objects: int, float, string, boolean, complex, tuple

# %%
x=5

# %%
id(x)  # is is used for getting the memory address of the object
# Out:
# 140704955442216

# %%
y=5
id(y) # id() is used for getting the memory address of the onject
    # As both above cases values is that's why same memory address for both
# Out:
# 140704952230952

# %%
a=[4,5,2]
id(a)
# Out:
# 2071242617152

# %%
b=[4,5,2]  # But here above 2 list having same elements still having different memory address
id(b)      # Means in mutable  different memory addresses.
# Out:
# 2071242513792

# %%
m="yogesh"
id(m)
# Out:
# 2071242321104

# %%
y="yogesh" #Immutable so having the same memory addresses
id(y)
# Out:
# 2071242321104

# %%
x= 12 #Global Immutable Variable
y=[4,5,6] #Global Mutable Variable

def myfun(a):
    k=5 #local variable inside the function
    b=a+6 #local variable
    c=b+3 #local variable
    print(k,b,c) #print values it because inside the function local variables are access
    return c

# %%
print(x,y) #Global variable can be access outside the function
# Out:
# 12 [4, 5, 6]

# %%
print(k,b,c) #Gives error as we are not able to access local variable outside the function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(k,b,c) #Gives error as we are not able to access local variable outside the function
#
# NameError: name 'k' is not defined

# %%
myfun(7) #Now it gives output as local variables access inside the function
# Out:
# 5 13 16
# 16

# %%
x= 12 #Global Immutable Variable
y=[4,5,6] #Global Mutable Variable
m=12

def myfun(a):
    print(x,y) #Global vairables are access inside the function
    c=x+5      #A function can access global variable.
    m=45
    print(m)
    y.append('Hi')
    print(x,y,m)
    return c

# %%
print(x,y,m) #Global variable call outside the function
# Out:
# 12 [4, 5, 6] 12

# %%
myfun(3)  # in function it gives all the updated values
# Out:
# 12 [4, 5, 6]
# 45
# 12 [4, 5, 6, 'Hi'] 45
# 17

# %%
print(x,y,m)  #Here outside the function only mutable values are upated for list but for x and m it gives 12 values only
# Out:
# 12 [4, 5, 6, 'Hi'] 12
