# %% [markdown]
# ## Object Oriented Programming

# %% [markdown]
# - Class - A template for an object - using class we can create multiple instances of it
#     - for example - we can think of employee profile as a class and using that profile, multiple objects(employees) can be created
# - Object : An instance of class
# - Functions define in class called as methods

# %%
class employee:
    name=" "
    age= 18
    salary=10000

# %%
# Creating as object of type class employee
# Creating as instance of the class employee
e1=employee()
e1 # e1 is an instance of class employee

# %%
print(e1.age,e1.salary)

# %%
e1.age=25
e1.salary=12000
e1.name="Yogesh"
print(e1.age,e1.salary,e1.name)

# %%
e2=employee()
e2.name="Shri"
e2.age=27
e2.salary=30000              
print(e2.age,e2.salary,e2.name)

# %%
type(e1)
type(e2)

# %%
e2.gender="Male"

# %%
print(e2.name,e2.gender)

# %%
print(e1.name,e1.salary)

# %%
class employee:
    name=" "
    age=18
    salary=10000
    def onboarding():
        print("Welcome to the company")

# %%
e1=employee()

# %%
e1.age=20
print(e1.age,e1.salary)

# %%
e1.onboarding()

# %%
# for solve this error we define self i.e. instance of class temperory instance
# as in java it is this but here it is self
class employee:
    name=" "
    age=18
    salary=10000
    def onboarding(self):
        print("Welcome to the company")

# %%
e2=employee()

# %%
e2.onboarding() # look now error is solve as now self it gives as 1 argument

# %%
class employee:
    name=" "
    age=18
    salary=10000
    def onboarding(self):
        print("Welcome to the company")
    def get_hike(self,percent):
        print("Current salary is ",self.salary)
        hike=percent*self.salary
        self.salary=self.salary + hike
        print("New Salary is ",self.salary)

# %%
e2=employee()

# %%
e2.get_hike(0.20)

# %% [markdown]
# ### Inheritance

# %%
class employee:
    name=" "
    age=18
    salary=10000
    def onboarding(self):
        print("Welcome to the company")
        return None
    def get_hike(self,percent):
        print("Current salary is ",self.salary)
        hike=percent*self.salary
        self.salary=self.salary + hike
        print("New Salary is ",self.salary)
        return self.salary
    def get_salary(self):
        print("Current Salary is ",self.salary)
        return None

class manager(employee):  #this is called inhertiance i.e. we can access all the methods from               class empployee in class manager 
    team_size=5
    businiess_domain="sales"
    age=20

    def hire_member(self,num_positions):
        print("Current team size is ",self.team_size)
        self.team_size=self.team_size + num_positions
        print("New team size is now ",self.team_size)

# %%
e1=employee()

# %%
e1.salary=20000

# %%
e1.get_hike(0.10)

# %%
m1=manager()

# %%
m1.name="Yogesh"
m1.age=25
print(m1.name,m1.age,m1.salary)

# %%
m1.get_hike(0.50)

# %%
m1.team_size

# %%
m1.hire_member(7)
