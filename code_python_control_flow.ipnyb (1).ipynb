# %% [markdown]
# ## Input Function in Python

# %%
 # Write code to ask user to enter two numbers and show the output.
a=input("Enter first number: ")
b=input("Enter second number: ")
print("The numbers entered are:",a,"and",b)
print(type(a),type(b))
c=a+b
print("The concatenated result is:",c)

# %%
a=int(input("Enter first number: "))
b=int(input("Enter first number: "))
print(type(a),type(b))
c=a+b
print("The sum of two numbers is:",c)

# %% [markdown]
# ### Task- BMI Calculator
#
# - write a python code create a BMI(Body to Mass Index) Calculator
#     - ask user to enter the weight in kg
#     - ask user to enter the height in cm
#
#     -Convert height from cm to meteres
#
#     Use below formula to calculate BMI
#     BMI= w/(h*h)
#     print(BMI)

# %%
weight= int(input("Enter your weight in kgs: "))
height= int(input("Enter your height in ceentimeteres: "))

height=height/100  # converting cm to meters

bmi= weight/(height*height)

print("Your BMI is:",round(bmi,2))

# %%
print("Your BMI is %.2f"%bmi)

# %%
x="Hey Hello %s your age is %d and BMI is %.3f"%("Yogesh",25,20.5777777)
print(x)

# %% [markdown]
# ### F-String

# %%
n="Yogesh"
age=12
salary=5000
bmi=25.2
m=f"Hey Hello my name is {n} and my age is {age} and my salary is {salary} and my BMI is {bmi}"
print(m)

# %% [markdown]
# ### Python Control Flow Statements
# #### Conditional Statements

# %%
weight= int(input("Enter your weight in kgs: "))
height= int(input("Enter your height in ceentimeteres: "))

height=height/100  # converting cm to meters

bmi= weight/(height*height)

print("Your BMI is:",round(bmi,2))

if(bmi<19):
    print("Your BMI is low")
    print("You are underweight")
    obesity="very low"
elif(bmi>=19 and bmi<25):
    print("Your BMI is normal")
    print("You are Healthy")
    obesity="Normal"
else:
    print("Your BMI is high")
    print("Your are Overweight")
    obesity="High"
print(obesity)

# %% [markdown]
# #### Loops in Python
# - Loops are used to repeat a set of codes mulitple times
#
#     - for loop - whenever exact count of repeatation is known
#     - while loop - Whenever the exact count of repeatation is not known, rather we want to perform condition based repeatation

# %%
print("Python is easy and amazing")
print("Python is easy and amazing")
print("Python is easy and amazing")
print("Python is easy and amazing")
print("Python is easy and amazing")

# %%
for i in range(5):
    print("Python is easy and amazing")

# %%
for i in range(5):
    print("Python is easy and amazing",i)

# %%
for i in range(3,8):
    print("Python is easy and amazing",i)

# %%
for i in range(3,8,2):
    print("Python is easy and amazing",i)

# %%
# for reverse order
for i in range(20,2,-2):
    print("Python is awesome",i)

# %%
# For loop also use iterate through the list

mylist=["DEL","DXB","MUM","CHE","BAN","BOM","AUH","AMD","MAA","DDN"]
mylist.sort(reverse=True)
for city in mylist:
    print("My city is =",city)

# %%
temp=[25,28,35,36,37,24,28,29,35,37.5,39]
for t in temp:
    if t>30:
        print("Temperature is : ",t)

# %% [markdown]
# #### While Loop

# %%
x=5
while(x<15):
    print("Python is amazing",x)
    x=x+1

# %% [markdown]
# ##### Guessing Game
# - Write code to
#     - create a variable ans=5
#     - Ask user to guess a number between o to 9
#     - Comapre the guess with ans
#     - if ans==guess
#         say "you won the jackpot"
#     - otherwise you need to say "try again"
#     - the user should get  chances to win the game

# %%
ans=5
for i in range(3):
    g=int(input("Enter the number between 0 to 9:"))
    if(g==ans):
        print("You Won The Jackpot")
        break
    else:
        print("Try Again")

# %%
ans=5
while True:
    g=int(input("Enter the number between 0 to 9:"))
    if g<0 or g>9:
        print("Invalid input, please enter a number between 0 to 9")
        continue # skip the rest and ask for input again and skip the execution below it
    if(g==ans):
        print("You Won The Jackpot")
        break
    else:
        print("Try Again")

# %%
for i in range(5): 
     pass # will write code here later

# %%
x=5
while True:
    x=x+1
    if(x>15):
        break
    print("The value of x is",x)
    if x%2==0:
        continue
    print("Python is amazing")
